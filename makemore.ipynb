# %% [markdown]
# <a href="https://colab.research.google.com/github/vipinkumarcp/llms_from_scratch/blob/main/makemore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
open('names.txt','r').read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1524255289.py in <cell line: 0>()
# ----> 1 open(names.txt,'r').read()
#
# NameError: name 'names' is not defined
